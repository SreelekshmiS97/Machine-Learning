# %%
#to avoid warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/abcnews-date-text.csv",error_bad_lines=False,nrows=20000)
data.head()
# Out:
#    publish_date                                      headline_text
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers

# %%
data.shape
# Out:
# (20000, 2)

# %%
#checking for duplicates in headlines
data[data['headline_text'].duplicated(keep=False)].sort_values('headline_text').head(10)
# Out:
#        publish_date                            headline_text
# 9253       20030404  5 australian sars cases being monitored
# 9458       20030405  5 australian sars cases being monitored
# 6192       20030321    all walks of life follow protest path
# 6402       20030322    all walks of life follow protest path
# 15880      20030507          an early taste of later battles
# 4597       20030313          an early taste of later battles
# 6409       20030322      asio briefs crean on terrorist risk
# 6197       20030321      asio briefs crean on terrorist risk
# 17498      20030515     athens olympic games tickets on sale
# 17065      20030513     athens olympic games tickets on sale

# %%
data = data.drop_duplicates('headline_text')

# %%
data.shape
# Out:
# (19938, 2)

# %% [markdown]
# ### Model 01
#
# Removing Stopwords

# %%
#we are importiting 2 functions from sklearn for NLP

from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
len(text.ENGLISH_STOP_WORDS) #ENGLISH_STOP_WORDS is a frozenset where all the stopwords are listed
# Out:
# 318

# %%
text.ENGLISH_STOP_WORDS
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
#selecting the stopwords and adding puctuations to it
punc = ['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']', '{', '}',"%"]
StopWords = text.ENGLISH_STOP_WORDS.union(punc)

# %%
StopWords
# Out:
# frozenset({'!',
#            '"',
#            '%',
#            "'",
#            '(',
#            ')',
#            ',',
#            '.',
#            ':',
#            ';',
#            '?',
#            '[',
#            ']',
#            'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves',
#            '{',
#            '}'})

# %%
len(StopWords)
# Out:
# 333

# %%
desc = data['headline_text'].values
desc #dataframe column is converted to an array.
# Out:
# array(['aba decides against community broadcasting licence',
#        'act fire witnesses must be aware of defamation',
#        'a g calls for infrastructure protection summit', ...,
#        'beattie praises federal govts environment effort',
#        'blackout cause still under investigation',
#        'boost planned for central vic tourism'], dtype=object)

# %%
vectorizer = TfidfVectorizer(stop_words = StopWords)
X=vectorizer.fit_transform(desc) #transorming desc to corresponding vector.

# %%
print("X is the TDIDF vector with %s rows and %s unique words(features)"%(X.shape[0],X.shape[1]))
# Out:
# X is the TDIDF vector with 19938 rows and 13838 unique words(features)

# %%
word_features = vectorizer.get_feature_names() #identiying the word from the vectors
word_features[500:510]
# Out:
# ['affairs',
#  'affect',
#  'affected',
#  'affecting',
#  'afffects',
#  'affiliate',
#  'affirms',
#  'afford',
#  'affordable',
#  'afghan']

# %%
X.shape  #we have 19938 observations and 13838 unique words present in the corpus 
# X will be the vector corresponding to data['headline_text']. This can be used for any ML tasks.
# Out:
# (19938, 13838)

# %% [markdown]
# ### Model 2
#
# Case Conversion
#
# Tokenization
#
# Stemming
#
# Removing Stopwords

# %%
#we are adding stemming  and tokenization to the preprocessing from the package NLTK
from nltk.stem.snowball import SnowballStemmer #SnowballStemmer is a stemming algorithm
from nltk.tokenize import RegexpTokenizer

# %%
stemmer = SnowballStemmer(language='english')
tokenizer = RegexpTokenizer(pattern=r'[a-zA-Z\']+')

def tokenize(text):
   
    return [stemmer.stem(word) for word in tokenizer.tokenize(text.lower())] 

#Step1 - Convert text to lower
#Step2 - Tokenize the text
#Step3 - Stem the tokenized text

#lower case
#tokenize
#stemming

# %%
def tokenize_function(text):
    lower_words = text.lower()
    tokenized = tokenizer.tokenize(lower_words)
    stem_list  = list()
    for x in tokenized:
        stem_list.append(stemmer.stem(x))
    return stem_list

# %%
tokenize_function("INDIA launched  2 new satelites, and the launch is Success")
# Out:
# ['india', 'launch', 'new', 'satelit', 'and', 'the', 'launch', 'is', 'success']

# %%
tokenize("INDIA launched  2 new satelites, and the launch is Success")
# Out:
# ['india', 'launch', 'new', 'satelit', 'and', 'the', 'launch', 'is', 'success']

# %%
tokenizer1 = RegexpTokenizer(r'[a-zA-Z0-9\']+') #new RegEx for including numbers
tokenizer1.tokenize("india launch  2 new satelites, and the launch is success")
# Out:
# ['india',
#  'launch',
#  '2',
#  'new',
#  'satelites',
#  'and',
#  'the',
#  'launch',
#  'is',
#  'success']

# %%
# ?TfidfVectorizer

# %%
vectorizer2 = TfidfVectorizer(stop_words = StopWords, tokenizer = tokenize) #we are giving StopWords and tokenize function as the arguments
X2 = vectorizer2.fit_transform(desc)
word_features2 = vectorizer2.get_feature_names()
print(len(word_features2))
# Out:
# 9504

# %%
X2.shape
# Out:
# (19938, 9504)

# %%
print("X2 is the TDIDF vector with %s rows and %s unique words(features)"%(X2.shape[0],X2.shape[1]))
# Out:
# X2 is the TDIDF vector with 19938 rows and 9504 unique words(features)

# %%
words = vectorizer2.get_feature_names()

# %%
words
# Out:
# ['aa',
#  'aac',
#  'aagaard',
#  'aagard',
#  'aapa',
#  'ab',
#  'aba',
#  'abalon',
#  'abandon',
#  'abar',
#  'abattoir',
#  'abba',
#  'abbott',
#  'abc',
#  'abdic',
#  'abduct',
#  'abductor',
#  'abe',
#  'abera',
#  'abetz',
#  'abid',
#  'abigroup',
#  'abil',
#  'abl',
#  'ablaz',
#  'ablett',
#  'aboard',
#  'abolish',
#  'abolit',
#  'aborigin',
#  'abort',
#  'abov',
#  'abreast',
#  'abroad',
#  'abrolho',
#  'absenc',
#  'absent',
#  'absurd',
#  'abu',
#  'abund',
#  'abus',
#  'abysm',
#  'ac',
#  'aca',
#  'academ',
#  'academi',
#  'acapulco',
#  'acb',
#  'acc',
#  'accc',
#  'acceler',
#  'accent',
#  'accept',
#  'access',
#  'accessori',
#  'accid',
#  'accident',
#  'accommod',
#  'account',
#  'accredit',
#  'accrington',
#  'accru',
#  'accus',
#  'ace',
#  'aceh',
#  'acehnes',
#  'achiev',
#  'achill',
#  'acid',
#  'acknowledg',
#  'acm',
#  'acon',
#  'acoss',
#  'acquir',
#  'acquisit',
#  'acquit',
#  'act',
#  'actew',
#  'action',
#  'activ',
#  'activist',
#  'actor',
#  'actress',
#  'actu',
#  'acu',
#  'ad',
#  'adam',
#  'add',
#  'addict',
#  'addit',
#  'address',
#  'addresss',
#  'adelaid',
#  'adequ',
#  'adf',
#  'adhd',
#  'adi',
#  'adjourn',
#  'adjust',
#  'admin',
#  'administr',
#  'admir',
#  'admiss',
#  'admit',
#  'adopt',
#  'adriatico',
#  'adrift',
#  'adult',
#  'adulteri',
#  'advanc',
#  'advantag',
#  'adventur',
#  'advertis',
#  'advic',
#  'advis',
#  'advisori',
#  'advoc',
#  'aec',
#  'aek',
#  'aerial',
#  'aerodynam',
#  'aeronaut',
#  'aeroplan',
#  'aeu',
#  'afc',
#  'affair',
#  'affect',
#  'afffect',
#  'affili',
#  'affirm',
#  'afford',
#  'afghan',
#  'afghanistan',
#  'afl',
#  'afloat',
#  'afma',
#  'afoot',
#  'afp',
#  'afraid',
#  'africa',
#  'african',
#  'afridi',
#  'aftermath',
#  'afternoon',
#  'aftershock',
#  'ag',
#  'agassi',
#  'age',
#  'agenc',
#  'agenda',
#  'agent',
#  'agfest',
#  'agforc',
#  'aggress',
#  'agist',
#  'agl',
#  'ago',
#  'agon',
#  'agoni',
#  'agonis',
#  'agre',
#  'agreement',
#  'agribusi',
#  'agricultur',
#  'aground',
#  'ah',
#  'aha',
#  'ahead',
#  'ahern',
#  'ai',
#  'aid',
#  'ail',
#  'aim',
#  'air',
#  'airbas',
#  'airborn',
#  'aircraft',
#  'airfield',
#  'airlift',
#  'airlin',
#  'airmen',
#  'airpark',
#  'airplay',
#  'airport',
#  'airspac',
#  'airstrip',
#  'airwomen',
#  'ajax',
#  'akbar',
#  'akhtar',
#  'akram',
#  'al',
#  'alain',
#  'alarm',
#  'albani',
#  'albert',
#  'albion',
#  'album',
#  'alburi',
#  'alchol',
#  'alcoa',
#  'alcohol',
#  'aldoga',
#  'alert',
#  'alexand',
#  'alfesco',
#  'alfi',
#  'alga',
#  'algal',
#  'algarv',
#  'algeria',
#  'algerian',
#  'ali',
#  'alianza',
#  'alic',
#  'alien',
#  'alight',
#  'align',
#  'alinghi',
#  'aliv',
#  'allan',
#  'allay',
#  'alleg',
#  'allen',
#  'allenbi',
#  'allergi',
#  'alli',
#  'allianc',
#  'alloc',
#  'allow',
#  'alon',
#  'alonso',
#  'alp',
#  'alpolfo',
#  'alreadi',
#  'alsac',
#  'alston',
#  'alterc',
#  'altern',
#  'aluminium',
#  'alvey',
#  'alway',
#  'alzheim',
#  'ama',
#  'amalgam',
#  'amateur',
#  'amaz',
#  'ambassador',
#  'ambit',
#  'ambiti',
#  'ambo',
#  'ambros',
#  'ambul',
#  'ambush',
#  'amc',
#  'amcor',
#  'amd',
#  'amelia',
#  'amend',
#  'ameri',
#  'america',
#  'american',
#  'ami',
#  'amid',
#  'amidst',
#  'amino',
#  'ammunit',
#  'amnesti',
#  'amoeba',
#  'amok',
#  'amoruso',
#  'amp',
#  'amphetamin',
#  'amput',
#  'ampute',
#  'amrozi',
#  'amstel',
#  'anaesthetist',
#  'analys',
#  'analyst',
#  'anarchi',
#  'anarchist',
#  'anasta',
#  'ancelotti',
#  'ancestr',
#  'anchor',
#  'ancic',
#  'ancient',
#  'anderson',
#  'andersson',
#  'andi',
#  'andretti',
#  'andrew',
#  'anfi',
#  'angel',
#  'anger',
#  'angl',
#  'angler',
#  'anglian',
#  'anglican',
#  'angri',
#  'angrili',
#  'ani',
#  'anim',
#  'ankl',
#  'anlezark',
#  'annan',
#  'annihil',
#  'anniversari',
#  'announc',
#  'annoy',
#  'annual',
#  'anoth',
#  'ansar',
#  'ansett',
#  'answer',
#  'ant',
#  'antarct',
#  'antarctica',
#  'antelop',
#  'anthem',
#  'anthrax',
#  'anthropologist',
#  'anti',
#  'antic',
#  'antidot',
#  'antisoci',
#  'antitrust',
#  'antonio',
#  'anu',
#  'anwar',
#  'anxieti',
#  'anxious',
#  'anz',
#  'anzac',
#  'anzelark',
#  'aoc',
#  'aol',
#  'apach',
#  'apart',
#  'apartheid',
#  'ape',
#  'aplenti',
#  'apn',
#  'apolog',
#  'apologis',
#  'appal',
#  'appar',
#  'appeal',
#  'appear',
#  'appeas',
#  'appetis',
#  'appl',
#  'applaud',
#  'applebi',
#  'appli',
#  'applic',
#  'appoint',
#  'appreci',
#  'apprentic',
#  'apprenticeship',
#  'approach',
#  'appropri',
#  'approv',
#  'apra',
#  'april',
#  'aprilia',
#  'aqi',
#  'aquacultur',
#  'aquat',
#  'aquif',
#  'arab',
#  'arabia',
#  'arabian',
#  'arabiya',
#  'arafat',
#  'arafura',
#  'aragon',
#  'aramac',
#  'arapil',
#  'arazi',
#  'arbitr',
#  'archaeolog',
#  'archaeologist',
#  'archbishop',
#  'archdioces',
#  'archeolog',
#  'archer',
#  'archibald',
#  'architect',
#  'architectur',
#  'ardil',
#  'ardmona',
#  'area',
#  'argentin',
#  'argentina',
#  'argentinean',
#  'argentinian',
#  'argi',
#  'argu',
#  'argument',
#  'ari',
#  'aris',
#  'aristocrat',
#  'arizona',
#  'arm',
#  'armadal',
#  'armageddon',
#  'armchair',
#  'arme',
#  'armenian',
#  'armi',
#  'armidal',
#  'armitag',
#  'armour',
#  'armstrong',
#  'arnett',
#  'arnhem',
#  'arnott',
#  'arrang',
#  'arrest',
#  'arriv',
#  'arrog',
#  'arron',
#  'arrow',
#  'arroyo',
#  'arsenal',
#  'arson',
#  'arsonist',
#  'art',
#  'artefact',
#  'arteri',
#  'arthur',
#  'articl',
#  'artifici',
#  'artilleri',
#  'artist',
#  'artwork',
#  'aru',
#  'asa',
#  'asap',
#  'asbesto',
#  'ascent',
#  'ase',
#  'asean',
#  'ash',
#  'asham',
#  'ashcroft',
#  'ashford',
#  'asia',
#  'asian',
#  'asic',
#  'asid',
#  'asio',
#  'ask',
#  'asphalt',
#  'aspinal',
#  'aspir',
#  'aspirin',
#  'assassin',
#  'assault',
#  'assembl',
#  'assess',
#  'asset',
#  'assist',
#  'assoc',
#  'associ',
#  'assum',
#  'assur',
#  'astarloa',
#  'asthma',
#  'aston',
#  'astonish',
#  'astound',
#  'astro',
#  'astronom',
#  'asx',
#  'asylum',
#  'atalanta',
#  'atapattu',
#  'athen',
#  'athlet',
#  'atkinson',
#  'atlant',
#  'atlas',
#  'atletico',
#  'atm',
#  'ato',
#  'atom',
#  'atop',
#  'atp',
#  'atroc',
#  'atsb',
#  'atsic',
#  'attach',
#  'attack',
#  'attempt',
#  'attend',
#  'attent',
#  'attitud',
#  'attorney',
#  'attract',
#  'attrit',
#  'atwal',
#  'auburn',
#  'auckland',
#  'auction',
#  'aud',
#  'audienc',
#  'audit',
#  'auditor',
#  'augathella',
#  'augenthal',
#  'august',
#  'augusta',
#  'auiron',
#  'aum',
#  'aurora',
#  'aus',
#  'ausmelt',
#  'aussi',
#  'aust',
#  'austeel',
#  'austereo',
#  'austin',
#  'austrad',
#  'australia',
#  'australian',
#  'austria',
#  'austrian',
#  'authent',
#  'author',
#  'autism',
#  'autist',
#  'auto',
#  'autobiographi',
#  'autonomi',
#  'autopsi',
#  'autumn',
#  'auxerr',
#  'auxiliari',
#  'av',
#  'avail',
#  'avalanch',
#  'ave',
#  'avellino',
#  'aveng',
#  'avenu',
#  'averag',
#  'aversen',
#  'avert',
#  'aviat',
#  'aviv',
#  'avocado',
#  'avoid',
#  'avon',
#  'await',
#  'awaken',
#  'awar',
#  'award',
#  'away',
#  'awb',
#  'awe',
#  'awol',
#  'awu',
#  'axe',
#  'axel',
#  'axeman',
#  'axi',
#  'ayatollah',
#  'aynaoui',
#  'ayr',
#  'azerbaijan',
#  'aziz',
#  'azul',
#  'azzurri',
#  'b',
#  'baath',
#  'baathist',
#  'babatund',
#  'babi',
#  'babri',
#  'babyhol',
#  'babylon',
#  'bacher',
#  'bachtiar',
#  'backbench',
#  'backdown',
#  'backdrop',
#  'backfir',
#  'backflip',
#  'backhand',
#  'backlash',
#  'backmark',
#  'backpack',
#  'backped',
#  'backstrok',
#  'backtrack',
#  'backup',
#  'backward',
#  'backyard',
#  'bacon',
#  'bad',
#  'baddeley',
#  'badger',
#  'baffl',
#  'bafta',
#  'bag',
#  'bagdad',
#  'baggi',
#  'baghdad',
#  'bahrain',
#  'bail',
#  'baildon',
#  'bailey',
#  'bairnsdal',
#  'bait',
#  'baiter',
#  'bakar',
#  'bakeri',
#  'balanc',
#  'balconi',
#  'bali',
#  'ball',
#  'ballack',
#  'ballad',
#  'ballarat',
#  'ballestero',
#  'ballina',
#  'ballist',
#  'balloon',
#  'ballot',
#  'ballymor',
#  'balonn',
#  'baltic',
#  'ban',
#  'banana',
#  'bandi',
#  'bandido',
#  'bandit',
#  'banfield',
#  'bang',
#  'banger',
#  'bangkok',
#  'bangladesh',
#  'bangladeshi',
#  'banish',
#  'bank',
#  'bankcard',
#  'banker',
#  'banknot',
#  'bankrobb',
#  'bankruptci',
#  'bankstown',
#  'bankwest',
#  'banner',
#  'banteng',
#  'baptist',
#  'bar',
#  'barassi',
#  'barbado',
#  'barbarian',
#  'barbequ',
#  'barbi',
#  'barca',
#  'barcelona',
#  'barcoo',
#  'bare',
#  'barg',
#  'bargain',
#  'bargin',
#  'bariton',
#  'bark',
#  'barker',
#  'barley',
#  'barman',
#  'barmera',
#  'barnard',
#  'barnett',
#  'barney',
#  'baromet',
#  'barossa',
#  'barr',
#  'barra',
#  'barrack',
#  'barrag',
#  'barrel',
#  'barrett',
#  'barri',
#  'barrichello',
#  'barrier',
#  'barrington',
#  'barrio',
#  'barrist',
#  'barthez',
#  'bartholomeuz',
#  'bartlett',
#  'barwon',
#  'barzan',
#  'base',
#  'basebal',
#  'basel',
#  'basement',
#  'bash',
#  'bashir',
#  'basi',
#  'basic',
#  'basin',
#  'basket',
#  'basketbal',
#  'basqu',
#  'basra',
#  'bass',
#  'basslink',
#  'bat',
#  'batch',
#  'batchelor',
#  'bateman',
#  'bathhous',
#  'batik',
#  'batman',
#  'batsmen',
#  'battalion',
#  'batten',
#  'batter',
#  'batteux',
#  'battl',
#  'battlefield',
#  'baumgartn',
#  'baxter',
#  'bay',
#  'bayarri',
#  'bayer',
#  'bayern',
#  'bayliss',
#  'bayswat',
#  'bbc',
#  'bcc',
#  'beach',
#  'beachley',
#  'beacon',
#  'bear',
#  'beat',
#  'beaten',
#  'beatl',
#  'beatti',
#  'beauti',
#  'beazley',
#  'becam',
#  'becaus',
#  'becker',
#  'beckham',
#  'beckon',
#  'becom',
#  'bed',
#  'bedi',
#  'bedouin',
#  'bedroom',
#  'bedtim',
#  'beechford',
#  'beef',
#  'beekeep',
#  'beer',
#  'beetl',
#  'befor',
#  'befriend',
#  'beg',
#  'bega',
#  'began',
#  'begay',
#  'beggar',
#  'begin',
#  'begun',
#  'behav',
#  'behaviour',
#  'behead',
#  'behrend',
#  'beij',
#  'beirut',
#  'bekel',
#  'bel',
#  'belfast',
#  'belfri',
#  'belgian',
#  'belgium',
#  'belgrad',
#  'believ',
#  'belittl',
#  'bell',
#  'bellami',
#  'bellevu',
#  'belli',
#  'belliger',
#  'belohvoscik',
#  'belt',
#  'bemax',
#  'benalla',
#  'benazzi',
#  'bench',
#  'benchmark',
#  'bendigo',
#  'beneath',
#  'benefactor',
#  'benefit',
#  'benin',
#  'benitez',
#  'bennett',
#  'bequeath',
#  'bequest',
#  'berger',
#  'bergkamp',
#  'berkov',
#  'berlin',
#  'berlusconi',
#  'bern',
#  'bernstein',
#  'berri',
#  'berrigan',
#  'berth',
#  'bertoletti',
#  'best',
#  'bestow',
#  'bestsel',
#  'bet',
#  'beti',
#  'better',
#  'bettini',
#  'bevan',
#  'bewar',
#  'bewild',
#  'bhoy',
#  'bhp',
#  'bhumibol',
#  'bhupathi',
#  'bhutan',
#  'bianchi',
#  'bias',
#  'bicci',
#  'bichel',
#  'bicker',
#  'bid',
#  'bidder',
#  'bide',
#  'big',
#  'bigger',
#  'biggest',
#  'bigmat',
#  'bigwig',
#  'bike',
#  'bikeway',
#  'biki',
#  'biktagirova',
#  'bilater',
#  'bilbao',
#  'bilbi',
#  'billion',
#  'billionair',
#  'billiton',
#  'billup',
#  'bin',
#  'bing',
#  'bingol',
#  'bio',
#  'biodivers',
#  'biofuel',
#  'biographi',
#  'biolog',
#  'biologist',
#  'biospher',
#  'biotech',
#  'bioterror',
#  'bipartisan',
#  'bird',
#  'birdi',
#  'birdsvill',
#  'birmingham',
#  'birth',
#  'birthday',
#  'birthplac',
#  'biscayn',
#  'biscuit',
#  'bishop',
#  'bite',
#  'bitten',
#  'black',
#  'blackal',
#  'blackburn',
#  'blacklock',
#  'blackmail',
#  'blackout',
#  'blackshirt',
#  'blade',
#  'blair',
#  'blake',
#  'blame',
#  'blank',
#  'blanket',
#  'blast',
#  'blatant',
#  'blatter',
#  'blayney',
#  'blaze',
#  'blazer',
#  'bleach',
#  'bleed',
#  'blend',
#  'bless',
#  'blew',
#  'blewett',
#  'bligh',
#  'blight',
#  'blignaut',
#  'blind',
#  'blitz',
#  'blix',
#  'blizzard',
#  'blob',
#  'block',
#  'blockad',
#  'bloke',
#  'blokey',
#  'blood',
#  'bloodi',
#  'bloodier',
#  'bloodsh',
#  'bloom',
#  'blow',
#  'blown',
#  'blowout',
#  'blowtorch',
#  'blu',
#  'blue',
#  'bluefin',
#  'blueprint',
#  'blumfield',
#  'blunder',
#  'bmw',
#  'boar',
#  'board',
#  'boarder',
#  'boardroom',
#  'boardshort',
#  'boast',
#  'boat',
#  'boati',
#  'boavista',
#  'bobetko',
#  'boca',
#  'bochum',
#  'bodi',
#  'bodyguard',
#  'boer',
#  'bog',
#  'boga',
#  'bogan',
#  'bok',
#  'boksic',
#  'bold',
#  'boldon',
#  'bolivar',
#  'bolivia',
#  'bolling',
#  'bolster',
#  'bolter',
#  'bolton',
#  'bomaderri',
#  'bomb',
#  'bombard',
#  'bombay',
#  'bomber',
#  'bonanza',
#  'bond',
#  'bone',
#  'bonlac',
#  'bonnet',
#  'bonus',
#  'boodnikoff',
#  'book',
#  'booki',
#  'booklet',
#  'bookmak',
#  'boom',
#  'boomer',
#  'boon',
#  'boonah',
#  'boost',
#  'booster',
#  'boot',
#  'booth',
#  'booz',
#  'bora',
#  'bordeau',
#  'bordeaux',
#  'border',
#  'bore',
#  'born',
#  'boro',
#  'borroloola',
#  'borrow',
#  'bortolo',
#  ...]

# %%
X2 #sparse matrix means most of the elements are 0

#Sparse matrix is a matrix which contains very few non-zero elements.
# Out:
# <19938x9504 sparse matrix of type '<class 'numpy.float64'>'
# 	with 97439 stored elements in Compressed Sparse Row format>

# %%
from sklearn.cluster import KMeans  #calculating wcss for identifying the value for K
wcss = []
for i in range(1,20):
    print("cluster",i)
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X2)
    wcss.append(kmeans.inertia_)
# Out:
# cluster 1
# cluster 2
# cluster 3
# cluster 4
# cluster 5
# cluster 6
# cluster 7
# cluster 8
# cluster 9
# cluster 10
# cluster 11
# cluster 12
# cluster 13
# cluster 14
# cluster 15
# cluster 16
# cluster 17
# cluster 18
# cluster 19

# %%
plt.plot(range(1,20),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
#plt.savefig('elbow.png')
plt.show()

# %%
kmeans = KMeans(n_clusters = 6, n_init = 20, n_jobs = 1) # n_init(number of iterations for clsutering) n_jobs(number of cpu cores to use)
kmeans.fit(X2)
# Out:
# KMeans(n_clusters=6, n_init=20, n_jobs=1)

# %%
common_words = kmeans.cluster_centers_.argsort()[:,-1:-16:-1] #checking for the most ffrequent words in each cluster
for num, centroid in enumerate(common_words):
    print(str(num) + ' : ' + ', '.join(words[word] for word in centroid))
# Out:
# 0 : man, win, face, charg, court, murder, jail, stab, hear, assault, drug, sex, die, hospit, death
# 1 : new, plan, sar, war, iraqi, say, claim, kill, fund, report, warn, baghdad, urg, protest, boost
# 2 : govt, vic, nsw, urg, sa, fund, wa, qld, fed, local, tas, reject, consid, claim, plan
# 3 : iraq, council, war, say, plan, troop, missil, urg, reject, consid, secur, bush, howard, blair, seek
# 4 : continu, bomb, australian, bali, search, iraqi, kill, baghdad, sar, suspect, suicid, blast, troop, war, trial
# 5 : polic, probe, investig, man, arrest, search, death, miss, fatal, drug, murder, car, charg, protest, road

# %%
result = kmeans.predict(X2)

# %%
data['result']=result #adding a new column to dataframe

# %%
data.head(25)
# Out:
#     publish_date                                      headline_text  result
# 0       20030219  aba decides against community broadcasting lic...       1
# 1       20030219     act fire witnesses must be aware of defamation       1
# 2       20030219     a g calls for infrastructure protection summit       1
# 3       20030219           air nz staff in aust strike for pay rise       1
# 4       20030219      air nz strike to affect australian travellers       4
# 5       20030219                  ambitious olsson wins triple jump       0
# 6       20030219         antic delighted with record breaking barca       1
# 7       20030219  aussie qualifier stosur wastes four memphis match       1
# 8       20030219       aust addresses un security council over iraq       3
# 9       20030219         australia is locked into war timetable opp       1
# 10      20030219  australia to contribute 10 million in aid to iraq       3
# 11      20030219  barca take record as robson celebrates birthda...       1
# 12      20030219                         bathhouse plans move ahead       1
# 13      20030219      big hopes for launceston cycling championship       1
# 14      20030219             big plan to boost paroo water supplies       1
# 15      20030219             blizzard buries united states in bills       1
# 16      20030219     brigadier dismisses reports troops harassed in       1
# 17      20030219     british combat troops arriving daily in kuwait       1
# 18      20030219         bryant leads lakers to double overtime win       0
# 19      20030219           bushfire victims urged to see centrelink       1
# 20      20030219    businesses should prepare for terrorist attacks       1
# 21      20030219    calleri avenges final defeat to eliminate massu       1
# 22      20030219            call for ethanol blend fuel to go ahead       1
# 23      20030219             carews freak goal leaves roma in ruins       1
# 24      20030219                       cemeteries miss out on funds       1
